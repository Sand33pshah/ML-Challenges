# %%
import pandas as pd
import numpy as np
train_data = pd.read_csv('data/Train.csv')
train_data.head(10)
# Out:
#            ID  Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# 0  FIN1000001      842001                4/16/2007            844120.0
# 1  FIN1000002      842001                4/16/2007            844111.0
# 2  FIN1000003      800001                4/16/2007            844101.0
# 3  FIN1000004      814112                4/16/2007            814112.0
# 4  FIN1000005      814112                4/16/2007            815351.0
# 5  FIN1000006      814112                4/16/2007            814114.0
# 6  FIN1000007      842001                4/16/2007            844118.0
# 7  FIN1000008      800001                4/16/2007            844103.0
# 8  FIN1000009      209625                4/16/2007            206451.0
# 9  FIN1000010      211001                4/16/2007            212218.0
#
#   Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# 0                M          12/19/1971                        M
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9527 entries, 0 to 9526
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           9527 non-null   object
#  1   Office_PIN                   9527 non-null   int64
#  2   Application_Receipt_Date     9527 non-null   object
#  3   Applicant_City_PIN           9430 non-null   float64
#  4   Applicant_Gender             9460 non-null   object
#  5   Applicant_BirthDate          9454 non-null   object
#  6   Applicant_Marital_Status     9454 non-null   object
#  7   Applicant_Occupation         8306 non-null   object
#  8   Applicant_Qualification      9441 non-null   object
#  9   Manager_DOJ                  8844 non-null   object
#  10  Manager_Joining_Designation  8844 non-null   object
#  11  Manager_Current_Designation  8844 non-null   object
#  12  Manager_Grade                8844 non-null   float64
# ...

# %%
train_data.isnull().sum()
# Out:
# ID                                0
# Office_PIN                        0
# Application_Receipt_Date          0
# Applicant_City_PIN               97
# Applicant_Gender                 67
# Applicant_BirthDate              73
# Applicant_Marital_Status         73
# Applicant_Occupation           1221
# Applicant_Qualification          86
# Manager_DOJ                     683
# Manager_Joining_Designation     683
# Manager_Current_Designation     683
# Manager_Grade                   683
# Manager_Status                  683
# Manager_Gender                  683
# Manager_DoB                     683
# Manager_Num_Application         683
# Manager_Num_Coded               683
# Manager_Business                683
# Manager_Num_Products            683
# Manager_Business2               683
# Manager_Num_Products2           683
# Business_Sourced                  0
# dtype: int64

# %%
train_data.shape
# Out:
# (9527, 23)

# %%
train_data.describe()
# Out:
#           Office_PIN  Applicant_City_PIN  Manager_Grade  \
# count    9527.000000         9430.000000    8844.000000
# mean   452894.372205       456784.547296       3.264134
# std    235690.618252       239291.081207       1.137449
# min    110005.000000       110001.000000       1.000000
# 25%    226001.000000       226020.000000       2.000000
# 50%    416001.000000       422005.500000       3.000000
# 75%    695014.000000       695017.000000       4.000000
# max    851101.000000       995657.000000      10.000000
#
#        Manager_Num_Application  Manager_Num_Coded  Manager_Business  \
# count              8844.000000        8844.000000      8.844000e+03
# mean                  1.939733           0.758933      1.843710e+05
# std                   2.150529           1.188644      2.747163e+05
# min                   0.000000           0.000000     -2.652890e+05
# 25%                   0.000000           0.000000      0.000000e+00
# ...

# %%
test_data = pd.read_csv('data/Test.csv')
test_data.head(10)
# Out:
#            ID  Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# 0  FIN1009528      284001                 7/2/2008            284001.0
# 1  FIN1009529      800001                 7/2/2008            800026.0
# 2  FIN1009530      800001                 7/2/2008                 NaN
# 3  FIN1009531      800001                 7/2/2008            844112.0
# 4  FIN1009532      533101                 7/2/2008            533102.0
# 5  FIN1009533      533101                 7/2/2008            533101.0
# 6  FIN1009534      533101                 7/2/2008            533261.0
# 7  FIN1009535      533101                 7/2/2008            533101.0
# 8  FIN1009536      533101                 7/2/2008            533288.0
# 9  FIN1009537      281001                 7/2/2008            281001.0
#
#   Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# 0                M            8/5/1982                        S
# ...

# %%
test_data.isnull().sum()
# Out:
# ID                                0
# Office_PIN                        0
# Application_Receipt_Date          0
# Applicant_City_PIN               34
# Applicant_Gender                 22
# Applicant_BirthDate              23
# Applicant_Marital_Status         30
# Applicant_Occupation           1004
# Applicant_Qualification          44
# Manager_DOJ                     824
# Manager_Joining_Designation     824
# Manager_Current_Designation     824
# Manager_Grade                   824
# Manager_Status                  824
# Manager_Gender                  824
# Manager_DoB                     824
# Manager_Num_Application         824
# Manager_Num_Coded               824
# Manager_Business                824
# Manager_Num_Products            824
# Manager_Business2               824
# Manager_Num_Products2           824
# dtype: int64

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5045 entries, 0 to 5044
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           5045 non-null   object
#  1   Office_PIN                   5045 non-null   int64
#  2   Application_Receipt_Date     5045 non-null   object
#  3   Applicant_City_PIN           5011 non-null   float64
#  4   Applicant_Gender             5023 non-null   object
#  5   Applicant_BirthDate          5022 non-null   object
#  6   Applicant_Marital_Status     5015 non-null   object
#  7   Applicant_Occupation         4041 non-null   object
#  8   Applicant_Qualification      5001 non-null   object
#  9   Manager_DOJ                  4221 non-null   object
#  10  Manager_Joining_Designation  4221 non-null   object
#  11  Manager_Current_Designation  4221 non-null   object
#  12  Manager_Grade                4221 non-null   float64
# ...

# %%
test_data.shape
# Out:
# (5045, 22)

# %%
train_data = train_data.drop('ID', axis = 1)
test_id = test_data['ID']
test_data = test_data.drop('ID',axis = 1)

# %%
import matplotlib.pyplot as plt
train_data.hist(bins = 40, figsize = (15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Office_PIN'}>,
#         <AxesSubplot:title={'center':'Applicant_City_PIN'}>,
#         <AxesSubplot:title={'center':'Manager_Grade'}>],
#        [<AxesSubplot:title={'center':'Manager_Num_Application'}>,
#         <AxesSubplot:title={'center':'Manager_Num_Coded'}>,
#         <AxesSubplot:title={'center':'Manager_Business'}>],
#        [<AxesSubplot:title={'center':'Manager_Num_Products'}>,
#         <AxesSubplot:title={'center':'Manager_Business2'}>,
#         <AxesSubplot:title={'center':'Manager_Num_Products2'}>],
#        [<AxesSubplot:title={'center':'Business_Sourced'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
corr_matrix = train_data.corr()
corr_matrix
# Out:
#                          Office_PIN  Applicant_City_PIN  Manager_Grade  \
# Office_PIN                 1.000000            0.977756      -0.077063
# Applicant_City_PIN         0.977756            1.000000      -0.091697
# Manager_Grade             -0.077063           -0.091697       1.000000
# Manager_Num_Application    0.061672            0.055152      -0.022524
# Manager_Num_Coded          0.066030            0.060603      -0.002833
# Manager_Business           0.093603            0.089794       0.322211
# Manager_Num_Products       0.132186            0.131358       0.210353
# Manager_Business2          0.093386            0.089425       0.320644
# Manager_Num_Products2      0.131747            0.130928       0.209886
# Business_Sourced           0.027682            0.028036       0.059363
#
#                          Manager_Num_Application  Manager_Num_Coded  \
# Office_PIN                              0.061672           0.066030
# ...

# %%
import seaborn as sns
sns.heatmap(corr_matrix, annot = True)
# Out:
# <AxesSubplot:>

# %%
corr_matrix['Business_Sourced']
corr_matrix['Business_Sourced'].sort_values(ascending = True)
# Out:
# Manager_Num_Application   -0.037593
# Manager_Num_Products2     -0.011706
# Manager_Num_Products      -0.011000
# Manager_Num_Coded          0.013565
# Office_PIN                 0.027682
# Applicant_City_PIN         0.028036
# Manager_Business2          0.031093
# Manager_Business           0.031578
# Manager_Grade              0.059363
# Business_Sourced           1.000000
# Name: Business_Sourced, dtype: float64

# %%
dropping = ['Application_Receipt_Date', 'Applicant_BirthDate', 
            'Manager_DOJ','Manager_DoB','Manager_Num_Products2',
            'Manager_Business2','Manager_Current_Designation',
           'Manager_Joining_Designation']
train_data = train_data.drop(dropping, axis = 1)
train_data.head()
# Out:
#    Office_PIN  Applicant_City_PIN Applicant_Gender Applicant_Marital_Status  \
# 0      842001            844120.0                M                        M
# 1      842001            844111.0                M                        S
# 2      800001            844101.0                M                        M
# 3      814112            814112.0                M                        S
# 4      814112            815351.0                M                        M
#
#   Applicant_Occupation Applicant_Qualification  Manager_Grade Manager_Status  \
# 0               Others                Graduate            3.0   Confirmation
# 1               Others               Class XII            3.0   Confirmation
# 2             Business               Class XII            2.0   Confirmation
# 3             Salaried               Class XII            4.0   Confirmation
# 4               Others               Class XII            2.0   Confirmation
#
# ...

# %%
test_data = test_data.drop(dropping, axis = 1)
test_data
# Out:
#       Office_PIN  Applicant_City_PIN Applicant_Gender  \
# 0         284001            284001.0                M
# 1         800001            800026.0                M
# 2         800001                 NaN                M
# 3         800001            844112.0                M
# 4         533101            533102.0                M
# ...          ...                 ...              ...
# 5040      691008            691601.0                F
# 5041      691008            691601.0                M
# 5042      691008            691005.0                M
# 5043      208001            208022.0                M
# 5044      122002            122001.0                M
#
#      Applicant_Marital_Status Applicant_Occupation  \
# 0                           S             Salaried
# 1                           M             Salaried
# 2                           S                  NaN
# 3                           S             Salaried
# 4                           S                  NaN
# ...

# %%
train_data.isnull().sum()
# Out:
# Office_PIN                     0
# Applicant_City_PIN            97
# Applicant_Gender              67
# Applicant_Marital_Status      73
# Applicant_Occupation        1221
# Applicant_Qualification       86
# Manager_Grade                683
# Manager_Status               683
# Manager_Gender               683
# Manager_Num_Application      683
# Manager_Num_Coded            683
# Manager_Business             683
# Manager_Num_Products         683
# Business_Sourced               0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Office_PIN                     0
# Applicant_City_PIN            34
# Applicant_Gender              22
# Applicant_Marital_Status      30
# Applicant_Occupation        1004
# Applicant_Qualification       44
# Manager_Grade                824
# Manager_Status               824
# Manager_Gender               824
# Manager_Num_Application      824
# Manager_Num_Coded            824
# Manager_Business             824
# Manager_Num_Products         824
# dtype: int64

# %%
num_columns = ['Manager_Num_Application','Manager_Num_Coded',
               'Manager_Business','Manager_Num_Products']
column1 = ['Applicant_City_PIN','Manager_Grade','Manager_Status',
           'Manager_Gender','Applicant_Gender','Applicant_Marital_Status',
           'Applicant_Occupation','Applicant_Qualification']

# %%
from sklearn.impute import SimpleImputer

imputer_num = SimpleImputer(missing_values = np.NaN, strategy = 'median')
train_data[num_columns] = imputer_num.fit_transform(train_data[num_columns])

# %%
imputer1 = SimpleImputer(missing_values = np.NaN, strategy = 'most_frequent')
train_data[column1] = imputer1.fit_transform(train_data[column1])

# %%
train_data.isnull().sum()
# Out:
# Office_PIN                  0
# Applicant_City_PIN          0
# Applicant_Gender            0
# Applicant_Marital_Status    0
# Applicant_Occupation        0
# Applicant_Qualification     0
# Manager_Grade               0
# Manager_Status              0
# Manager_Gender              0
# Manager_Num_Application     0
# Manager_Num_Coded           0
# Manager_Business            0
# Manager_Num_Products        0
# Business_Sourced            0
# dtype: int64

# %%
imputer_num = SimpleImputer(missing_values = np.NaN, strategy = 'median')
test_data[num_columns] = imputer_num.fit_transform(test_data[num_columns])

imputer1 = SimpleImputer(missing_values = np.NaN, strategy = 'most_frequent')
test_data[column1] = imputer1.fit_transform(test_data[column1])

# %%
test_data.isnull().sum()
# Out:
# Office_PIN                  0
# Applicant_City_PIN          0
# Applicant_Gender            0
# Applicant_Marital_Status    0
# Applicant_Occupation        0
# Applicant_Qualification     0
# Manager_Grade               0
# Manager_Status              0
# Manager_Gender              0
# Manager_Num_Application     0
# Manager_Num_Coded           0
# Manager_Business            0
# Manager_Num_Products        0
# dtype: int64

# %%
train_data.head()
# Out:
#    Office_PIN  Applicant_City_PIN Applicant_Gender Applicant_Marital_Status  \
# 0      842001            844120.0                M                        M
# 1      842001            844111.0                M                        S
# 2      800001            844101.0                M                        M
# 3      814112            814112.0                M                        S
# 4      814112            815351.0                M                        M
#
#   Applicant_Occupation Applicant_Qualification  Manager_Grade Manager_Status  \
# 0               Others                Graduate            3.0   Confirmation
# 1               Others               Class XII            3.0   Confirmation
# 2             Business               Class XII            2.0   Confirmation
# 3             Salaried               Class XII            4.0   Confirmation
# 4               Others               Class XII            2.0   Confirmation
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
non_numerical = ['Applicant_Gender','Applicant_Marital_Status',
                  'Applicant_Occupation','Applicant_Qualification',
                 'Manager_Status','Manager_Gender']
for i in non_numerical:
    train_data[i] = le.fit_transform(train_data[i])

# %%
for j in non_numerical:
    test_data[j] = le.fit_transform(test_data[j])

# %%
train_data
# Out:
#       Office_PIN  Applicant_City_PIN  Applicant_Gender  \
# 0         842001            844120.0                 1
# 1         842001            844111.0                 1
# 2         800001            844101.0                 1
# 3         814112            814112.0                 1
# 4         814112            815351.0                 1
# ...          ...                 ...               ...
# 9522      160017            160032.0                 1
# 9523      848101            848302.0                 1
# 9524      753012            753014.0                 0
# 9525      575003            571248.0                 1
# 9526      411006            411006.0                 0
#
#       Applicant_Marital_Status  Applicant_Occupation  Applicant_Qualification  \
# 0                            1                     1                        7
# 1                            2                     1                        6
# ...

# %%
test_data
# Out:
#       Office_PIN  Applicant_City_PIN  Applicant_Gender  \
# 0         284001            284001.0                 1
# 1         800001            800026.0                 1
# 2         800001            492001.0                 1
# 3         800001            844112.0                 1
# 4         533101            533102.0                 1
# ...          ...                 ...               ...
# 5040      691008            691601.0                 0
# 5041      691008            691601.0                 1
# 5042      691008            691005.0                 1
# 5043      208001            208022.0                 1
# 5044      122002            122001.0                 1
#
#       Applicant_Marital_Status  Applicant_Occupation  Applicant_Qualification  \
# 0                            2                     2                        4
# 1                            1                     2                        4
# ...

# %%
from sklearn.preprocessing import StandardScaler

X = train_data.drop('Business_Sourced', axis = 1)
Y = train_data['Business_Sourced']


scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(scaled_X, Y, train_size = 0.80,
                                                    shuffle = True, stratify = Y)

# %%
y_test.head()
# Out:
# 3473    0
# 2762    0
# 8071    1
# 4007    1
# 1167    0
# Name: Business_Sourced, dtype: int64

# %%
y_train
# Out:
# 4840    0
# 6496    0
# 565     0
# 1934    0
# 159     0
#        ..
# 7111    0
# 5107    0
# 2795    1
# 5917    0
# 3874    0
# Name: Business_Sourced, Length: 7621, dtype: int64

# %%
from sklearn.metrics import roc_auc_score, classification_report

# %%
from sklearn.linear_model import LinearRegression as LiR

classifier5 = LiR(normalize = True)
classifier5.fit(x_train, y_train)
predicted_values = classifier5.predict(x_test)
print('ROC : ', roc_auc_score(y_test, predicted_values)*100, '%')
# Out:
# ROC :  57.4661581225391 %

# %%
scaler2 = StandardScaler()
scaled_test_data = scaler2.fit_transform(test_data)

# %%
submission = pd.DataFrame()
submission['ID'] = test_id
submission['Business_Sourced'] = classifier5.predict(scaled_test_data)
submission.head(30)
# Out:
#             ID  Business_Sourced
# 0   FIN1009528          0.304833
# 1   FIN1009529          0.332465
# 2   FIN1009530          0.342308
# 3   FIN1009531          0.401217
# 4   FIN1009532          0.288255
# 5   FIN1009533          0.304805
# 6   FIN1009534          0.226182
# 7   FIN1009535          0.304805
# 8   FIN1009536          0.334301
# 9   FIN1009537          0.344173
# 10  FIN1009538          0.395310
# 11  FIN1009539          0.404803
# 12  FIN1009540          0.376612
# 13  FIN1009541          0.356953
# 14  FIN1009542          0.335534
# 15  FIN1009543          0.407517
# 16  FIN1009544          0.471357
# 17  FIN1009545          0.372631
# 18  FIN1009546          0.272166
# 19  FIN1009547          0.245657
# 20  FIN1009548          0.417309
# 21  FIN1009549          0.221739
# 22  FIN1009550          0.407877
# 23  FIN1009551          0.482409
# 24  FIN1009552          0.407517
# 25  FIN1009553          0.319256
# 26  FIN1009554          0.456383
# ...

# %%
submission.to_csv("my_submission_LiR_2.csv", index = False)
